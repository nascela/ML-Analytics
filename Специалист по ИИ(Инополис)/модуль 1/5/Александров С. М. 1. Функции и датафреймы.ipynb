# %%
import pandas as pd
bike = pd.read_csv('bike.csv', sep=',')

# %%
# Out:
#                  datetime  season  holiday  workingday  weather   temp  \
# 0     2011-01-01 00:00:00       1        0           0      1.0   9.84
# 1     2011-01-01 01:00:00       1        0           0      1.0   9.02
# 2     2011-01-01 02:00:00       1        0           0      1.0   9.02
# 3     2011-01-01 03:00:00       1        0           0      1.0   9.84
# 4     2011-01-01 04:00:00       1        0           0      1.0   9.84
# ...                   ...     ...      ...         ...      ...    ...
# 7800  2012-06-05 19:00:00       2        0           1      1.0  23.78
# 7801  2012-06-05 20:00:00       2        0           1      1.0  22.96
# 7802  2012-06-05 21:00:00       2        0           1      1.0  22.14
# 7803  2012-06-05 22:00:00       2        0           1      1.0  22.96
# 7804  2012-06-05 23:00:00       2        0           1      1.0  22.14
#
#        atemp  humidity  windspeed  casual  registered  count
# ...

# %%
bike.shape
# Out:
# (7805, 12)

# %%
bike.head(5)
# Out:
#               datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  2011-01-01 00:00:00       1        0           0      1.0  9.84  14.395
# 1  2011-01-01 01:00:00       1        0           0      1.0  9.02  13.635
# 2  2011-01-01 02:00:00       1        0           0      1.0  9.02  13.635
# 3  2011-01-01 03:00:00       1        0           0      1.0  9.84  14.395
# 4  2011-01-01 04:00:00       1        0           0      1.0  9.84  14.395
#
#    humidity  windspeed  casual  registered  count
# 0      81.0        0.0       3          13     16
# 1      80.0        0.0       8          32     40
# 2      80.0        0.0       5          27     32
# 3      75.0        0.0       3          10     13
# 4      75.0        0.0       0           1      1

# %%
bike.tail(7)
# Out:
#                  datetime  season  holiday  workingday  weather   temp  \
# 7798  2012-06-05 17:00:00       2        0           1      1.0  24.60
# 7799  2012-06-05 18:00:00       2        0           1      1.0  24.60
# 7800  2012-06-05 19:00:00       2        0           1      1.0  23.78
# 7801  2012-06-05 20:00:00       2        0           1      1.0  22.96
# 7802  2012-06-05 21:00:00       2        0           1      1.0  22.14
# 7803  2012-06-05 22:00:00       2        0           1      1.0  22.96
# 7804  2012-06-05 23:00:00       2        0           1      1.0  22.14
#
#        atemp  humidity  windspeed  casual  registered  count
# 7798  31.060      43.0     0.0000      86         764    850
# 7799  31.060      43.0    12.9980     111         679    790
# 7800  27.275      46.0    16.9979      68         445    513
# 7801  26.515      49.0    15.0013      44         371    415
# 7802  25.760      56.0    11.0014      30         253    283
# ...

# %%
bike.columns
# Out:
# Index(['datetime', 'season', 'holiday', 'workingday', 'weather', 'temp',
#        'atemp', 'humidity', 'windspeed', 'casual', 'registered', 'count'],
#       dtype='object')

# %%
bike.head(3).T
# Out:
#                               0                    1                    2
# datetime    2011-01-01 00:00:00  2011-01-01 01:00:00  2011-01-01 02:00:00
# season                        1                    1                    1
# holiday                       0                    0                    0
# workingday                    0                    0                    0
# weather                     1.0                  1.0                  1.0
# temp                       9.84                 9.02                 9.02
# atemp                    14.395               13.635               13.635
# humidity                   81.0                 80.0                 80.0
# windspeed                   0.0                  0.0                  0.0
# casual                        3                    8                    5
# registered                   13                   32                   27
# count                        16                   40                   32

# %%
bike.info
# Out:
# <bound method DataFrame.info of                  datetime  season  holiday  workingday  weather   temp  \
# 0     2011-01-01 00:00:00       1        0           0      1.0   9.84
# 1     2011-01-01 01:00:00       1        0           0      1.0   9.02
# 2     2011-01-01 02:00:00       1        0           0      1.0   9.02
# 3     2011-01-01 03:00:00       1        0           0      1.0   9.84
# 4     2011-01-01 04:00:00       1        0           0      1.0   9.84
# ...                   ...     ...      ...         ...      ...    ...
# 7800  2012-06-05 19:00:00       2        0           1      1.0  23.78
# 7801  2012-06-05 20:00:00       2        0           1      1.0  22.96
# 7802  2012-06-05 21:00:00       2        0           1      1.0  22.14
# 7803  2012-06-05 22:00:00       2        0           1      1.0  22.96
# 7804  2012-06-05 23:00:00       2        0           1      1.0  22.14
#
#        atemp  humidity  windspeed  casual  registered  count
# ...

# %%
bike.describe
# Out:
# <bound method NDFrame.describe of                  datetime  season  holiday  workingday  weather   temp  \
# 0     2011-01-01 00:00:00       1        0           0      1.0   9.84
# 1     2011-01-01 01:00:00       1        0           0      1.0   9.02
# 2     2011-01-01 02:00:00       1        0           0      1.0   9.02
# 3     2011-01-01 03:00:00       1        0           0      1.0   9.84
# 4     2011-01-01 04:00:00       1        0           0      1.0   9.84
# ...                   ...     ...      ...         ...      ...    ...
# 7800  2012-06-05 19:00:00       2        0           1      1.0  23.78
# 7801  2012-06-05 20:00:00       2        0           1      1.0  22.96
# 7802  2012-06-05 21:00:00       2        0           1      1.0  22.14
# 7803  2012-06-05 22:00:00       2        0           1      1.0  22.96
# 7804  2012-06-05 23:00:00       2        0           1      1.0  22.14
#
#        atemp  humidity  windspeed  casual  registered  count
# ...

# %%
for i in range(4, 20):
    print(bike['windspeed'][i])
# Out:
# 0.0
# 6.0032
# 0.0
# 0.0
# 0.0
# 0.0
# 16.9979
# 19.0012
# 19.0012
# 19.9995
# 19.0012
# 19.9995
# 19.9995
# 19.0012
# 16.9979
# 16.9979

# %%
print(bike['windspeed'][5])
# Out:
# 6.0032

# %%
for i in range(len(bike.index)):
    if(bike['temp'][i] > bike['atemp'][i]):
        print(bike['temp'][i])
# Out:
# 5.74
# 7.38
# 6.56
# 4.1
# 4.1
# 4.1
# 4.1
# 4.1
# 4.92
# 5.74
# 6.56
# 7.38
# 5.74
# 8.2
# 8.2
# 6.56
# 5.74
# 8.2
# 7.38
# 6.56
# 5.74
# 4.1
# 4.1
# 4.1
# 12.3
# 11.48
# 10.66
# 6.56
# 4.92
# 9.84
# 8.2
# 8.2
# 10.66
# 10.66
# 6.56
# 7.38
# 7.38
# 7.38
# 6.56
# 6.56
# 5.74
# 5.74
# 5.74
# 4.92
# 4.1
# 3.28
# 1.64
# 0.82
# 0.82
# 12.3
# 9.84
# 10.66
# 10.66
# 10.66
# 10.66
# 11.48
# 10.66
# 10.66
# 8.2
# 6.56
# 5.74
# 5.74
# 4.92
# 4.1
# 3.28
# 4.1
# 4.1
# 4.1
# 4.1
# 4.1
# 5.74
# 6.56
# 6.56
# 6.56
# 6.56
# 11.48

# %%
goodTemp = []
for i in range(len(bike.index)):
    goodTemp.append(bike['temp'][i] > bike['atemp'][i])
bike['good_temp'] = goodTemp
bike.head(5)
# Out:
#               datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  2011-01-01 00:00:00       1        0           0      1.0  9.84  14.395
# 1  2011-01-01 01:00:00       1        0           0      1.0  9.02  13.635
# 2  2011-01-01 02:00:00       1        0           0      1.0  9.02  13.635
# 3  2011-01-01 03:00:00       1        0           0      1.0  9.84  14.395
# 4  2011-01-01 04:00:00       1        0           0      1.0  9.84  14.395
#
#    humidity  windspeed  casual  registered  count  good_temp
# 0      81.0        0.0       3          13     16      False
# 1      80.0        0.0       8          32     40      False
# 2      80.0        0.0       5          27     32      False
# 3      75.0        0.0       3          10     13      False
# 4      75.0        0.0       0           1      1      False

# %%
is_null = bike.isnull()
row_with_null = is_null.any(axis=1)                    
rows_with_null = bike[row_with_null]
rows_with_null
# Out:
#                  datetime  season  holiday  workingday  weather   temp  \
# 273   2011-01-12 20:00:00       1        0           1      NaN   6.56
# 281   2011-01-13 04:00:00       1        0           1      1.0   5.74
# 343   2011-01-15 19:00:00       1        0           0      2.0  13.12
# 727   2011-02-14 02:00:00       1        0           1      1.0  14.76
# 977   2011-03-05 14:00:00       1        0           0      NaN  19.68
# 1049  2011-03-08 16:00:00       1        0           1      1.0  15.58
# 1114  2011-03-11 12:00:00       1        0           1      2.0    NaN
# 1115  2011-03-11 13:00:00       1        0           1      1.0    NaN
# 1179  2011-03-14 07:00:00       1        0           1      2.0  11.48
#
#        atemp  humidity  windspeed  casual  registered  count  good_temp
# 273    6.820      50.0    22.0028       2          54     56      False
# 281    6.060      50.0        NaN       0           4      4      False
# ...

# %%
bike[(bike['windspeed'] > 20) & (bike['temp'] > 20) ].head(5)
# Out:
#                 datetime  season  holiday  workingday  weather   temp   atemp  \
# 737  2011-02-14 12:00:00       1        0           1      1.0  22.96  26.515
# 738  2011-02-14 13:00:00       1        0           1      1.0  23.78  27.275
# 739  2011-02-14 14:00:00       1        0           1      1.0  24.60  29.545
# 740  2011-02-14 15:00:00       1        0           1      1.0  22.96  26.515
# 741  2011-02-14 16:00:00       1        0           1      1.0  21.32  25.000
#
#      humidity  windspeed  casual  registered  count  good_temp
# 737      22.0    30.0026      27          99    126      False
# 738      19.0    26.0027      27          93    120      False
# 739      15.0    32.9975      14          76     90      False
# 740      21.0    43.9989      19          71     90      False
# 741      27.0    31.0009      16         102    118      False

# %%
bike[(bike['windspeed'] > 20) & (bike['temp'] > 20) ].head(5).iloc[2]
# Out:
# datetime      2011-02-14 14:00:00
# season                          1
# holiday                         0
# workingday                      1
# weather                       1.0
# temp                         24.6
# atemp                      29.545
# humidity                     15.0
# windspeed                 32.9975
# casual                         14
# registered                     76
# count                          90
# good_temp                   False
# Name: 739, dtype: object

# %%
bike.sort_values('count', ascending=False)
# Out:
#                  datetime  season  holiday  workingday  weather   temp  \
# 7606  2012-05-16 17:00:00       2        0           1      1.0  29.52
# 7631  2012-05-17 18:00:00       2        0           1      1.0  27.06
# 7630  2012-05-17 17:00:00       2        0           1      1.0  27.06
# 7798  2012-06-05 17:00:00       2        0           1      1.0  24.60
# 7607  2012-05-16 18:00:00       2        0           1      1.0  29.52
# ...                   ...     ...      ...         ...      ...    ...
# 942   2011-03-04 03:00:00       1        0           1      2.0   7.38
# 919   2011-03-03 04:00:00       1        0           1      1.0   6.56
# 918   2011-03-03 03:00:00       1        0           1      1.0   8.20
# 916   2011-03-03 01:00:00       1        0           1      1.0   9.84
# 6516  2012-03-09 04:00:00       1        0           1      3.0  16.40
#
#        atemp  humidity  windspeed  casual  registered  count  good_temp
# ...

# %%
dfSeasons = pd.DataFrame(
    [
        [1, 'spring'],
        [2, 'summer'],
        [3, 'fall'],
        [4, 'winter']
    ],
    columns=['season', 'nameseason']
)

# %%
dfSeasons
# Out:
#    season nameseason
# 0       1     spring
# 1       2     summer
# 2       3       fall
# 3       4     winter

# %%
pd.merge( 
    bike,
    dfSeasons
)
# Out:
#                  datetime  season  holiday  workingday  weather   temp  \
# 0     2011-01-01 00:00:00       1        0           0      1.0   9.84
# 1     2011-01-01 01:00:00       1        0           0      1.0   9.02
# 2     2011-01-01 02:00:00       1        0           0      1.0   9.02
# 3     2011-01-01 03:00:00       1        0           0      1.0   9.84
# 4     2011-01-01 04:00:00       1        0           0      1.0   9.84
# ...                   ...     ...      ...         ...      ...    ...
# 7800  2011-12-19 19:00:00       4        0           1      2.0  14.76
# 7801  2011-12-19 20:00:00       4        0           1      1.0  16.40
# 7802  2011-12-19 21:00:00       4        0           1      2.0  14.76
# 7803  2011-12-19 22:00:00       4        0           1      2.0  14.76
# 7804  2011-12-19 23:00:00       4        0           1      1.0  14.76
#
#        atemp  humidity  windspeed  casual  registered  count  good_temp  \
# ...

# %%
bike.sort_values('count').sort_values('season')
# Out:
#                  datetime  season  holiday  workingday  weather   temp  \
# 6647  2012-03-14 16:00:00       1        0           1      1.0  29.52
# 6393  2012-03-04 01:00:00       1        0           0      2.0  15.58
# 1289  2011-03-19 00:00:00       1        0           0      2.0  24.60
# 427   2011-01-19 20:00:00       1        0           1      1.0  13.12
# 1298  2011-03-19 09:00:00       1        0           0      1.0  17.22
# ...                   ...     ...      ...         ...      ...    ...
# 4082  2011-10-02 13:00:00       4        0           0      3.0  16.40
# 4898  2011-11-17 14:00:00       4        0           1      2.0  13.94
# 4558  2011-11-03 10:00:00       4        0           1      2.0  16.40
# 5071  2011-12-05 19:00:00       4        0           1      2.0  18.86
# 5241  2011-12-12 21:00:00       4        0           1      1.0  10.66
#
#        atemp  humidity  windspeed  casual  registered  count  good_temp
# ...

# %%
groupBike = bike.groupby(['season', 'count'])
groupBike.first()
# Out:
#                          datetime  holiday  workingday  weather   temp  \
# season count
# 1      1      2011-01-01 04:00:00        0           0      1.0   9.84
#        2      2011-01-01 06:00:00        0           0      1.0   9.02
#        3      2011-01-01 07:00:00        0           0      1.0   8.20
#        4      2011-01-04 05:00:00        0           1      1.0   4.92
#        5      2011-01-03 00:00:00        0           1      1.0   9.02
# ...                           ...      ...         ...      ...    ...
# 4      591    2011-10-05 17:00:00        0           1      1.0  26.24
#        593    2011-10-05 18:00:00        0           1      1.0  24.60
#        604    2011-10-11 17:00:00        0           1      2.0  24.60
#        620    2011-10-17 17:00:00        0           1      1.0  22.96
#        625    2011-10-18 17:00:00        0           1      1.0  24.60
#
#                atemp  humidity  windspeed  casual  registered  good_temp
# season count
# ...

# %%
d = bike.pivot_table(
    'weather', 'season', 'atemp')
d
# Out:
# atemp   0.760   1.515     2.275     3.030   3.790   4.545   5.305     6.060   \
# season
# 1          1.0     1.0  1.571429  1.142857    1.25     1.0    1.08  1.191781
# 2          NaN     NaN       NaN       NaN     NaN     NaN     NaN       NaN
# 3          NaN     NaN       NaN       NaN     NaN     NaN     NaN       NaN
# 4          NaN     NaN       NaN       NaN     NaN     NaN     NaN       NaN
#
# atemp     6.820     7.575   ...    36.365    37.120    37.880    38.635  \
# season                      ...
# 1       1.225806  1.356164  ...       NaN       NaN       NaN       NaN
# 2            NaN       NaN  ...  1.700000  1.375000  1.111111  1.000000
# 3            NaN       NaN  ...  1.111111  1.163636  1.235294  1.086957
# 4            NaN  1.000000  ...       NaN       NaN       NaN       NaN
#
# atemp   39.395    40.150  40.910  41.665  42.425  43.940
# season
# 1          NaN       NaN     NaN     NaN     NaN     NaN
# ...
